# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

amazon_data_path = '/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw/Amazon Sale Report.csv'

df = pd.read_csv(amazon_data_path)

df.head()
# Out:
# /var/folders/jh/7d3zkbt12k76jb3h3twj7s4w0000gn/T/ipykernel_5806/509437772.py:7: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(amazon_data_path)
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='str')

# %%
len(df)
# Out:
# 128975

# %%
df.shape
# Out:
# (128975, 24)

# %%
df['Order ID'].nunique()
# Out:
# 120378

# %%
df.iloc[2].nunique()
# Out:
# 20

# %%
df.iloc[:,2].nunique()
# Out:
# 91

# %%
unique_values = []
null_values = []
for i in range(0,df.shape[1]):
    unique_values.append([df.columns[i], df.iloc[:,i].nunique()])
    null_values.append([df.columns[i], df.iloc[:,i].isna().sum().item()])

print( unique_values, '\n', null_values )
# Out:
# [['index', 128975], ['Order ID', 120378], ['Date', 91], ['Status', 13], ['Fulfilment', 2], ['Sales Channel ', 2], ['ship-service-level', 2], ['Style', 1377], ['SKU', 7195], ['Category', 9], ['Size', 11], ['ASIN', 7190], ['Courier Status', 3], ['Qty', 10], ['currency', 1], ['Amount', 1410], ['ship-city', 8955], ['ship-state', 69], ['ship-postal-code', 9459], ['ship-country', 1], ['promotion-ids', 5787], ['B2B', 2], ['fulfilled-by', 1], ['Unnamed: 22', 1]]
#  [['index', 0], ['Order ID', 0], ['Date', 0], ['Status', 0], ['Fulfilment', 0], ['Sales Channel ', 0], ['ship-service-level', 0], ['Style', 0], ['SKU', 0], ['Category', 0], ['Size', 0], ['ASIN', 0], ['Courier Status', 6872], ['Qty', 0], ['currency', 7795], ['Amount', 7795], ['ship-city', 33], ['ship-state', 33], ['ship-postal-code', 33], ['ship-country', 33], ['promotion-ids', 49153], ['B2B', 0], ['fulfilled-by', 89698], ['Unnamed: 22', 49050]]
