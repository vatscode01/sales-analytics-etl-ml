# %%
import sys

sys.path.append('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/etl')

from extract import get_amazon_data

df = get_amazon_data()

# Remove Duplicates

df = df.drop_duplicates()

df_backup = df
# Out:
# /Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/etl/extract.py:18: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
# Standarize column name

df.columns = df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace('-','_')

df.columns = df.columns.str.lower()
df.columns = df.columns.str.rstrip('_')
df.columns = df.columns.str.replace(' ','_')

df.head()
# Out:
#    index             order_id      date                        status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   fulfilment sales_channel ship_service_level    style              sku  \
# 0   Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         category  ... currency  amount    ship_city   ship_state  \
# ...

# %%
# import pandas as pd

# location = '/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data'
# df_amazon = df[['index','order_id','date','status','sales_channel','amount']]
# df_amazon.to_csv(location + '/amazon_main')
# Out:
#          index             order_id      date                        status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
#        sales_channel   amount
# ...

# %%
# df['amount'].apply(lambda x : x<0 : x*=-1)

df['amount'] = df['amount'].apply(lambda x: abs(x))
df.head()
# Out:
#    index             order_id      date                        status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   fulfilment sales_channel ship_service_level    style              sku  \
# 0   Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         category  ... currency  amount    ship_city   ship_state  \
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
# location = '/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/cleaned'
# df.to_csv(location + '/cleaned.csv')

# print("Saved cleaned csv file in data/cleaned")

# %%
# location = '/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/cleaned'
# df.to_excel(location + '/cleaned.xlsx')

# %%
import pandas as pd
import psycopg2 as pg2

pg2.connect(database = 'test', user = 'postgres', password = 'aady_02')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       2 import psycopg2 as pg2
#       3
# ----> 4 pg2.connect(database = 'test', user = 'postgres', password = 'aady_02')
#
# File ~/Desktop/Ayush Vats/ETL Pipeline Project/.venv/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server on socket "/tmp/.s.PGSQL.5432" failed: FATAL:  database "test" does not exist

# %%
# import sys
# sys.path.append('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw')

import pandas as pd

df_amazon = pd.read_csv('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw/Amazon Sale Report.csv')

df_amazon.head()
# Out:
# /var/folders/jh/7d3zkbt12k76jb3h3twj7s4w0000gn/T/ipykernel_14420/3599346618.py:6: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_amazon = pd.read_csv('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw/Amazon Sale Report.csv')
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# ...

# %%
df.columns
# Out:
# Index(['index', 'order_id', 'date', 'status', 'fulfilment', 'sales_channel',
#        'ship_service_level', 'style', 'sku', 'category', 'size', 'asin',
#        'courier_status', 'qty', 'currency', 'amount', 'ship_city',
#        'ship_state', 'ship_postal_code', 'ship_country', 'promotion_ids',
#        'b2b', 'fulfilled_by', 'unnamed:_22'],
#       dtype='str')

# %%
df_sales = pd.read_csv('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw/Sale Report.csv')
df_sales = df_sales.set_index(keys = 'order_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 df_sales = pd.read_csv('/Users/aady/Desktop/Ayush Vats/ETL Pipeline Project/data/raw/Sale Report.csv')
# ----> 2 df_sales = df_sales.set_index(keys = 'order_id')
#
# File ~/Desktop/Ayush Vats/ETL Pipeline Project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:6989, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6985                     if not found:
#    6986                         missing.append(col)
#    6987
#    6988         if missing:
# -> 6989             raise KeyError(f"None of {missing} are in the columns")
#    6990
#    6991         if inplace:
#    6992             frame = self
#
# KeyError: "None of ['order_id'] are in the columns"

# %%
for i in range(0,df_sales.shape[1]):
    print(df_sales.columns[i], df_sales.iloc[:,i].isna().sum())
    print(df_sales.columns[i] , df_sales.iloc[:,i].nunique())
    print("")
print(df_sales['index'].nunique())
# Out:
# index 0
# index 9271
#
# SKU Code 83
# SKU Code 9170
#
# Design No. 36
# Design No. 1594
#
# Stock 36
# Stock 295
#
# Category 45
# Category 21
#
# Size 36
# Size 11
#
# Color 45
# Color 62
#
# 9271

# %%
for i in range(0,df_amazon.shape[1]):
    print(df_amazon.columns[i] , df_amazon.iloc[:,i].isna().sum())
# Out:
# index 0
# Order ID 0
# Date 0
# Status 0
# Fulfilment 0
# Sales Channel  0
# ship-service-level 0
# Style 0
# SKU 0
# Category 0
# Size 0
# ASIN 0
# Courier Status 6872
# Qty 0
# currency 7795
# Amount 7795
# ship-city 33
# ship-state 33
# ship-postal-code 33
# ship-country 33
# promotion-ids 49153
# B2B 0
# fulfilled-by 89698
# Unnamed: 22 49050
